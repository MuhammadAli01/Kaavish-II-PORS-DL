# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = 'My Drive/Deep Fashion Retrieval'

ROOT = "/content/drive"
PROJECT_PATH = os.path.join(ROOT, MY_GOOGLE_DRIVE_PATH)

print("PROJECT_PATH: ", PROJECT_PATH)
os.chdir(PROJECT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/My Drive/Deep Fashion Retrieval

# %%
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
from os.path import join  

# path to your project on Google Drive
# MY_GOOGLE_DRIVE_PATH = 'My Drive/Deep Fashion Retrieval/deep-fashion-retrieval'
MY_GOOGLE_DRIVE_PATH = 'My Drive/Deep Fashion Retrieval' 
# replace with your Github username 
GIT_USERNAME = "MuhammadAli01" 
# definitely replace with your
GIT_TOKEN = "66ddaf72d5181a2f8f9e54e01af34d702bd22a22"  
# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "Kaavish-II-PORS-DL" 

ROOT = "/content/drive"
PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/My Drive/Deep Fashion Retrieval
# mkdir: cannot create directory ‘/content/drive/My Drive/Deep Fashion Retrieval’: File exists
# GIT_PATH:  https://66ddaf72d5181a2f8f9e54e01af34d702bd22a22@github.com/MuhammadAli01/Kaavish-II-PORS-DL.git

# %%
# Change directory to the location defined in project_path
import os
os.chdir(PROJECT_PATH)

# %%
# ! git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Deep Fashion Retrieval/.git/

# %%
# ! git remote add origin "{GIT_PATH}"

# %%
# ! echo base >> .gitignore

# %%
! git remote -v
# Out:
# origin	https://66ddaf72d5181a2f8f9e54e01af34d702bd22a22@github.com/MuhammadAli01/Kaavish-II-PORS-DL.git (fetch)
# origin	https://66ddaf72d5181a2f8f9e54e01af34d702bd22a22@github.com/MuhammadAli01/Kaavish-II-PORS-DL.git (push)

# %%
! git add *
# Out:
# The following paths are ignored by one of your .gitignore files:
# base
# Use -f if you really want to add them.
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> deep-fashion-retrieval
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached deep-fashion-retrieval
# hint:
# hint: See "git help submodule" for more information.

# %%
! git commit -m "export classification output of scrapped dataset"
# Out:
# [master a37bbac] export classification output of scrapped dataset
#  3 files changed, 78 insertions(+), 12 deletions(-)

# %%
! git push -u origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 1.03 KiB | 1.03 MiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/MuhammadAli01/Kaavish-II-PORS-DL.git
#    7df180e..a37bbac  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# ! git config --global user.email "m_ali98@outlook.com"
# ! git config --global user.name "MuhammadAli01"
